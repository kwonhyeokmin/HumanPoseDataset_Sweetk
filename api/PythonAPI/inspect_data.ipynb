# %%
from utils import Dataset2d
import os
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt

# %%
ROOT_DIR = os.path.join(os.getcwd(), '../..')
DATA_DIR = os.path.join(ROOT_DIR, 'datasets')

# %%
dataset = Dataset2d()
dataset.load_data(DATA_DIR)
# Out:
# loading data into memory...
# Done (t=0s)
# Image Count: 1020

# %%
img_id = 680

# %%
# Original Image
plt.figure(figsize=(10, 8))
plt.axis('off')
plt.imshow(dataset.load_image(dataset.image_ids[img_id]))
plt.show()

# %%
# Show keypoints
plt.figure(figsize=(10, 8))
dataset.display_instance(dataset.image_ids[img_id])
plt.show()

# %%
# Show keypoints with bounding box
plt.figure(figsize=(10, 8))
dataset.display_instance(dataset.image_ids[img_id], show_bbox=True)
plt.show()
