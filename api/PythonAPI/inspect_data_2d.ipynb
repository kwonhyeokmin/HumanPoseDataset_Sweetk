# %%
import os
from utils import Dataset2d, Dataset3d
from matplotlib import pyplot as plt

# %%
ROOT_DIR = '/Users/kwon/PycharmProjects/SweetDataset'
DATA_DIR = os.path.join(ROOT_DIR, 'datasets')

# %%
dataset_2d = Dataset2d()
dataset_2d.load_data(DATA_DIR)
# Out:
# loading data into memory...
# Done (t=0s)
# Image Count: 216

# %%
img_no = dataset_2d.image_ids[0]

# %%
plt.figure(figsize=(10, 8))
plt.axis('off')
plt.imshow(dataset_2d.load_image(img_no))
plt.show()

# %%
plt.figure(figsize=(10, 8))
dataset_2d.display_instance(img_no)
plt.show()

# %%
plt.figure(figsize=(10, 8))
dataset_2d.display_instance(img_no, True)
plt.show()
