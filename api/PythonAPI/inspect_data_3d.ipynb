# %%
import os
from utils import Dataset2d, Dataset3d
from matplotlib import pyplot as plt

# %%
ROOT_DIR = '/Users/kwon/PycharmProjects/SweetDataset'
DATA_DIR = os.path.join(ROOT_DIR, 'datasets')

# %%
dataset_3d = Dataset3d()
dataset_3d.load_data(DATA_DIR)
# Out:
# loading data into memory...
# Done (t=0s)
# Image Count: 216

# %%
img_no = dataset_3d.image_ids[0]

# %%
plt.figure(figsize=(10, 10))
plt.axis('off')
plt.imshow(dataset_3d.load_image(img_no))
plt.show()

# %%
dataset_3d.vis_3d_skeleton(img_no)
